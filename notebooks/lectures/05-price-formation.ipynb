# %% [markdown]
# # Price formation
#
# Section 1.4 of the notes, at the keyboard, and the destination of the chapter.  The order
# flow imbalance is first an accounting identity and then a forecast, and the two are
# different claims with different evidence.

# %% [markdown]
# ## 1. The identity comes first
#
# Under the idealised book the mid-price change over a window is the imbalance times
# $\tau/(2\bar S)$, plus a residual bounded by one tick.  This is arithmetic, not a
# prediction, and it is the route the measurement must agree with.

# %%
# build a session; compute e_n and OFI_{t,w}
# MarketSession.order_flow_imbalance(Window(w))

# %% [markdown]
# ## 2. Computing the contribution
#
# Both indicators fire when the best price is unchanged, so such an event contributes the
# change in the size resting there.  An event that moves the quote contributes a whole
# queue.

# %%
# session._order_flow_contribution against the definition, one elementary event at a time
# the padded-touch case: NaN >= NaN is False on both sides, and gives a plain 0

# %% [markdown]
# ## 3. The slope, and the depth it implies
#
# Regress the mid-price change on the imbalance and read the depth back out of the slope.
# Then ask how much of the gap the residual accounts for.

# %%
# imbalance_regression.predictors, backward_change; estimation.ols, estimation.hac_variance

# %% [markdown]
# ## 4. Forward is a different question
#
# Contemporaneously the two regimes agree, and that agreement is accounting.  Forward
# they disagree in sign, and that sign belongs to the kernel.

# %%
# config.example_order_flow_params vs trending_order_flow_params
# .signed_endogenous_fraction; forward_change over a grid of horizons

# %% [markdown]
# ## 5. The imbalance of the book, read asymmetrically
#
# This laboratory has no adverse selection, so whatever forecasting power $I^1$ retains
# here is mechanical.  A result favouring OFI is not evidence it dominates in a traded
# market; a result favouring $I^1$ would be the stronger finding.

# %%
# I^1 against OFI at the same horizons; state the asymmetry before reading the numbers

# %% [markdown]
# ## 6. The outcome is a lattice with an atom
#
# The mid-price change does not move on nine rows in ten, so $R^2$ is the wrong score and
# quantile-binning the outcome merges flat with up.  Bin the predictor; take the outcome
# as three sign classes.

# %%
# estimation.ThreeClassModel, .log_score_skill, .incremental_log_score_skill
# show what quantile-binning the outcome actually returns

# %% [markdown]
# ## 7. Not fooling ourselves
#
# The window, the row set, the statistic, the direction and the threshold were written
# down before the confirmatory run, on seeds that had been read by nothing.  We read that
# document and say which numbers in this notebook are confirmatory and which are not.

# %%
# documentation/pre-registration-imbalance-regression.md -- the four claims
# estimation.purged_folds, estimation.bootstrap_means, signed_covariance

# %% [markdown]
# ## 8. What recorded data would settle
#
# The assignment, and the two questions that cannot be asked of generated flow at all.

# %%
# the LOBSTER pair again; the five parts of the assignment, and where each one starts
